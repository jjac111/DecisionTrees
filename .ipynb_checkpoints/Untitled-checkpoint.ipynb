# %%
from utils import *

# %%
prepare_data()

make_folded_sets()
# Out:
# Raw dataset:
#      0   1   2   3   4   5   6   8   10  13  ...  31  33  34  37  39  40  41  \
# 42    0  59  68  69  67  69  59  73  65  74  ...  75  59  61  73  81  75  74
# 220   1  62  63  66  62  67  66  79  55  52  ...  72  58  63  76  67  58  54
# 254   0  68  70  69  74  65  70  73  68  68  ...  74  70  72  60  69  62  66
# 13    1  70  69  67  66  68  60  77  67  79  ...  74  67  59  73  74  68  77
# 263   0  72  61  64  66  64  59  66  66  71  ...  72  56  56  67  69  68  65
# 50    0  64  70  71  69  72  70  78  66  68  ...  77  65  64  59  71  74  68
# 94    1  62  54  65  65  24  31  66  54  47  ...  66  60  60  55  68  71  31
# 166   1  75  75  64  63  58  58  77  74  69  ...  61  58  47  59  60  57  63
# 98    1  67  59  54  48  63  67  78  61  59  ...  45  38  43  80  61  48  63
# 53    0  65  67  69  76  62  68  66  64  60  ...  76  65  63  69  69  74  69
# 155   1  59  75  77  80  60  64  67  68  69  ...  79  67  66  70  60  65  61
# ...

# %%
metrics = classify('ID3')
plot_results(metrics)
# Out:
# The tree looks like this:
# root
# ├── F30 (0.0, 0.2) => 1
# ├── F30 (0.2, 0.4) => 1
# ├── F30 (0.4, 0.6) => 1
# ├── F30 (0.6, 0.8)
# │   ├── F9 (0.0, 0.2) => 1
# │   ├── F9 (0.2, 0.4) => 1
# │   ├── F9 (0.4, 0.6) => 1
# │   ├── F9 (0.6, 0.8)
# │   │   ├── F5 (0.2, 0.4) => 1
# │   │   ├── F5 (0.4, 0.6) => 1
# │   │   ├── F5 (0.6, 0.8) => 1
# │   │   └── F5 (0.8, 1.0)
# │   │       ├── F14 (0.4, 0.6)
# │   │       │   ├── F1 (0.6, 0.8) => 0
# │   │       │   └── F1 (0.8, 1.0) => 1
# │   │       ├── F14 (0.6, 0.8) => 1
# │   │       └── F14 (0.8, 1.0) => 0
# │   └── F9 (0.8, 1.0) => 1
# └── F30 (0.8, 1.0)
#     ├── F10 (0.2, 0.4) => 1
#     ├── F10 (0.4, 0.6) => 1
#     ├── F10 (0.6, 0.8)
#     │   ├── F6 (0.2, 0.4) => 1
#     │   ├── F6 (0.4, 0.6) => 1
#     │   ├── F6 (0.6, 0.8)
#     │   │   ├── F9 (0.4, 0.6) => 0
#     │   │   ├── F9 (0.6, 0.8)
#     │   │   │   ├── F17 (0.0, 0.2) => 1
#     │   │   │   ├── F17 (0.4, 0.6)
#     │   │   │   │   ├── F1 (0.2, 0.4) => 1
# ...

# %%
metrics = classify('C4.5')
plot_results(metrics)
# Out:
# The tree looks like this:
# root
# ├── F34 (0.0, 0.2) => 1
# ├── F34 (0.2, 0.4) => 1
# ├── F34 (0.4, 0.6)
# │   ├── F31 (0.0, 0.2) => 1
# │   ├── F31 (0.2, 0.4) => 1
# │   ├── F31 (0.4, 0.6) => 1
# │   ├── F31 (0.6, 0.8) => 1
# │   └── F31 (0.8, 1.0)
# │       ├── F21 (0.2, 0.4) => 1
# │       ├── F21 (0.4, 0.6)
# │       │   ├── F3 (0.6, 0.8) => 0
# │       │   └── F3 (0.8, 1.0) => 1
# │       ├── F21 (0.6, 0.8)
# │       │   ├── F28 (0.2, 0.4) => 0
# │       │   ├── F28 (0.6, 0.8) => 1
# │       │   └── F28 (0.8, 1.0) => 1
# │       └── F21 (0.8, 1.0) => 1
# ├── F34 (0.6, 0.8)
# │   ├── F28 (0.0, 0.2) => 1
# │   ├── F28 (0.2, 0.4)
# │   │   ├── F2 (0.0, 0.2) => 1
# │   │   ├── F2 (0.6, 0.8) => 1
# │   │   └── F2 (0.8, 1.0) => 0
# │   ├── F28 (0.4, 0.6)
# │   │   ├── F5 (0.2, 0.4) => 1
# │   │   ├── F5 (0.4, 0.6)
# │   │   │   ├── F11 (0.4, 0.6) => 1
# │   │   │   ├── F11 (0.6, 0.8) => 0
# │   │   │   └── F11 (0.8, 1.0) => 1
# │   │   ├── F5 (0.6, 0.8)
# ...

# %%
metrics = classify('CART')
plot_results(metrics)
# Out:
# The tree looks like this:
# root
# ├── F16 (0.0, 0.2) => 1
# ├── F16 (0.2, 0.4) => 1
# ├── F16 (0.4, 0.6)
# │   ├── F5 (0.4, 0.6) => 1
# │   ├── F5 (0.6, 0.8)
# │   │   ├── F10 (0.0, 0.2) => 1
# │   │   ├── F10 (0.4, 0.6) => 1
# │   │   └── F10 (0.8, 1.0)
# │   │       ├── F9 (0.6, 0.8)
# │   │       │   └── F17 (0.6, 0.8)
# │   │       │       ├── F1 (0.4, 0.6)
# │   │       │       │   └── F2 (0.4, 0.6)
# │   │       │       │       └── F4 (0.6, 0.8)
# │   │       │       │           └── F18 (0.6, 0.8)
# │   │       │       │               └── F25 (0.6, 0.8)
# │   │       │       │                   ├── F3 (0.2, 0.4) => 1
# │   │       │       │                   └── F3 (0.6, 0.8) => 0
# │   │       │       └── F1 (0.6, 0.8) => 1
# │   │       └── F9 (0.8, 1.0) => 1
# │   └── F5 (0.8, 1.0)
# │       ├── F14 (0.0, 0.2) => 1
# │       └── F14 (0.4, 0.6)
# │           ├── F9 (0.2, 0.4) => 1
# │           └── F9 (0.8, 1.0)
# │               └── F12 (0.8, 1.0)
# ...
